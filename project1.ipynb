# %% [markdown]
# Project title:
# “What AI skills are most valuable in the job market?”
# -Which AI skills are associated with higher salaries
# -Which countries pay more for specific AI roles
# -Whether the most discussed skills online are also the best paid
# -Which skills seem undervalued or overhyped.

# %%
 import pandas as pd
df = pd.read_csv("ai_job_dataset.csv")
display(df)

# %%
df.info()

# %%
df.columns

# %%
df = df.drop(columns=[
    'job_id',
    'job_description_length',
    'company_name',
    'application_deadline',
    'posting_date'
])

# %%
df['salary_currency'].unique()

# %%
df['salary_currency'].value_counts()

# %%
#df.groupby('required_skills')['salary_usd'].mean()

# %%
#df_skills = df.copy()

#df_skills['required_skills'] = df_skills['required_skills'].str.split(',')

#df_skills = df_skills.explode('required_skills')

#df_skills['required_skills'] = df_skills['required_skills'].str.strip().str.lower()

# %%
#skill_salary = df_skills.groupby('required_skills')['salary_usd'].mean()

# %%
#top_skills = skill_salary.sort_values(ascending=False).head(15)

#print(top_skills)

# %%
#skill_counts = df_skills['required_skills'].value_counts()

#valid_skills = skill_counts[skill_counts > 20].index  # threshold

#filtered = df_skills[df_skills['required_skills'].isin(valid_skills)]

#top_skills = filtered.groupby('required_skills')['salary_usd'].mean().sort_values(ascending=False).head(15)

# %%
#salary and demand
#result = pd.DataFrame({
   # 'avg_salary': filtered.groupby('required_skills')['salary_usd'].mean(),
  #  'count': filtered['required_skills'].value_counts()
#})

#result.sort_values(by='avg_salary', ascending=False).head(15)

# %%
#df['required_skills'] \
 # .str.split(',') \
  #.explode() \
  #.str.strip() \
 # .unique()
